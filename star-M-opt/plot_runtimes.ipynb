# %%
from star_m_product import
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import sys, os
# ----> 2 sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), "..")))
#       3
#       4 import pystarm
#       5 import numpy as np
#
# NameError: name '__file__' is not defined
